# %% [markdown]
# ### Given original image lena.jpg identify the operations applied on the images lena1.jpg, lena2.jpg and lena3.jpg.

# %%
# %matplotlib inline

import numpy as np
import cv2
from matplotlib import pyplot as plt
import math

# %%
img = cv2.imread('./DIP_2019_A1/lena.jpg',0)
img_q = cv2.imread('./DIP_2019_A1/lena.jpg')
img1 = cv2.imread('./DIP_2019_A1/lena1.jpg',0)
img2 = cv2.imread('./DIP_2019_A1/lena2.jpg',0)
img3 = cv2.imread('./DIP_2019_A1/lena3.jpg',0)

lst = []
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
         lst.append(np.binary_repr(img[i][j] ,width=8))

# %%
def BitQuantizeImage(img, k):
    d = 2**(8-k)
    b, g, r = cv2.split(img)
    
    for i in range(0, b.shape[0]):
        for j in range(0, b.shape[1]):
            b[i][j] = math.floor(b[i][j]/d)*d

    for i in range(0, g.shape[0]):
        for j in range(0, g.shape[1]):
            g[i][j] = math.floor(g[i][j]/d)*d

    for i in range(0, r.shape[0]):
        for j in range(0, r.shape[1]):
            r[i][j] = math.floor(r[i][j]/d)*d
            
    img1 = cv2.merge([r,g,b])
    return img1

# %%
quan_img = BitQuantizeImage(img_q, 2)
plt.imshow(quan_img)
plt.show()

# %%
eight_bit_img = (np.array([int(i[0]) for i in lst],dtype = np.uint8) * 128).reshape(img.shape[0],img.shape[1])
seven_bit_img = (np.array([int(i[1]) for i in lst],dtype = np.uint8) * 64).reshape(img.shape[0],img.shape[1])
six_bit_img = (np.array([int(i[2]) for i in lst],dtype = np.uint8) * 32).reshape(img.shape[0],img.shape[1])
five_bit_img = (np.array([int(i[3]) for i in lst],dtype = np.uint8) * 16).reshape(img.shape[0],img.shape[1])
four_bit_img = (np.array([int(i[4]) for i in lst],dtype = np.uint8) * 8).reshape(img.shape[0],img.shape[1])
three_bit_img = (np.array([int(i[5]) for i in lst],dtype = np.uint8) * 4).reshape(img.shape[0],img.shape[1])
two_bit_img = (np.array([int(i[6]) for i in lst],dtype = np.uint8) * 2).reshape(img.shape[0],img.shape[1])
one_bit_img = (np.array([int(i[7]) for i in lst],dtype = np.uint8) * 1).reshape(img.shape[0],img.shape[1])

# %%
plt.imshow(eight_bit_img, cmap='gray')
plt.show()

# %% [markdown]
# - Similar to lena3.jpg

# %%
plt.imshow(seven_bit_img, cmap='gray')
plt.show()

# %%
plt.imshow(six_bit_img, cmap='gray')
plt.show()

# %% [markdown]
# - Similar to lena1.jpg

# %%
plt.imshow(five_bit_img, cmap='gray')
plt.show()

# %%
plt.imshow(four_bit_img, cmap='gray')
plt.show()

# %%
plt.imshow(three_bit_img, cmap='gray')
plt.show()

# %%
plt.imshow(two_bit_img, cmap='gray')
plt.show()

# %%
plt.imshow(one_bit_img, cmap='gray')
plt.show()
